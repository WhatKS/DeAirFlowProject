# %%
import pandas as pd

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_json('/Users/lq/PycharmProjects/DeAirFlowProject/data/raw/movies.json')
df = pd.DataFrame(df)

# %%
missing = df.isnull()
has_missing = missing.any(axis=1)

# %%
df_modified = df.drop(columns=['backdrop_path'])

# %%
df_with_missing = df_modified[has_missing]

# %%
df_with_missing
# Out:
#      adult     genre_ids       id original_language  \
# 59   False            []  1030419                ja
# 60   False          [99]   287003                en
# 110  False          [27]   888838                en
# 138  False          [53]   960096                es
# 552  False      [28, 16]   370455                ja
# 699  False            []   931019                en
# 700  False          [35]   367401                it
# 724  False  [27, 14, 53]  1034541                en
# 770  False            []   466353                ja
# 778  False   [10749, 18]   845659                en
# 790  False  [28, 80, 53]   385687                en
# 807  False          [18]   197158                pt
# 888  False            []   631330                ja
# 890  False       [10749]   485470                ko
# 924  False          [99]   278698                en
# 961  False       [10749]   721187                ko
#
#                    original_title  \
# 59     銀河英雄伝説 Die Neue These 策謀 1
# 60   Avatar: Scene Deconstruction
# 110           The Long Dark Trail
# 138                      El monte
# 552           ワンパンマン ロード・トゥー・ヒーロー
# 699       Avatar: Enter The World
# 700      Con la zia non è peccato
# 724                   Terrifier 3
# 770                         暴虐女拷問
# 778             Perfect Addiction
# 790                        Fast X
# 807                        Pornô!
# 888                  女子高生物語 淫らな果実
# 890                        착한 형수2
# 924                Avatar Spirits
# 961               미용실 : 특별한 서비스 4
#
#                                               overview  popularity  \
# 59                                                         373.889
# 60    The deconstruction of the Avatar scenes and sets     510.037
# 110  After two impoverished teenage brothers manage...     202.685
# 138  A father and son, isolated in a dilapidated co...     176.205
# 552  Defeating numerous villains in the abandoned a...      64.104
# 699  A behind the scenes look at the new James Came...      74.102
# 700  The rich Gloria, resident for years in the Uni...      47.484
# 724  In the aftermath of Terrifier 2, the third ins...      50.555
# 770  In the end of the 19th century, social restora...      54.348
# 778  When successful boxing trainer Sienna Lane dis...      32.530
# 790            The tenth installment in the Fast Saga.      49.774
# 807  Three tales of the erotic: Two young ladies ex...      52.780
# 888                                                         52.978
# 890  If you give it once, a good brother-in-law who...      38.071
# 924  Bryan Konietzko and Michael Dante DiMartino, c...      63.220
# 961  Focusing on the relationship between men and w...      46.956
#
#                           poster_path release_date  \
# 59   /brrgSFtcymZWaXl5a23GJRWdOSY.jpg   2022-09-30
# 60   /uCreCQFReeF0RiIXkQypRYHwikx.jpg   2009-12-18
# 110  /ebdDGnqQXDGfiggHSazaWCLF6Lf.jpg   2021-06-19
# 138  /xlwt27iWubh6DEiQhc3kyVMjCU5.jpg   2022-08-18
# 552  /bMNkufYM0kaDRJ0OVSHF91Ftdyr.jpg   2015-12-04
# 699  /9MHY9pYAgs91Ef7YFGWEbP4WJqC.jpg   2009-12-05
# 700  /qn9UmLXCpWPKcMCFWQcpF8PCq3W.jpg   1980-12-23
# 724  /A2ouWngHdomaAyFAPMI7VOpOLvS.jpg
# 770  /eVWWh9k3Mr5DQRnnjBnzdnJfE6K.jpg   1978-01-14
# 778                              None   2023-02-16
# 790  /zWJHY9QYzEcXmQ7BUg0qJxSICzd.jpg   2023-05-18
# 807  /bhbPSpYjsRJAK7rXqL8APK9EwBl.jpg   1981-01-01
# 888  /yCGcw3m94cA9ON52MrPEynkK3Fx.jpg   1997-10-10
# 890  /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 924  /oBWVyOdntLJd5bBpE0wkpN6B6vy.jpg   2010-06-22
# 961  /nJpoe1CKuiqh90qUliO6qHCeNYI.jpg   2020-05-04
#
#                                                  title  video  vote_average  \
# 59   Legend of the Galactic Heroes: Die Neue These ...  False           5.5
# 60                        Avatar: Scene Deconstruction  False           8.3
# 110                                The Long Dark Trail  False           5.1
# 138                                           The Bush  False           5.0
# 552                        One Punch Man: Road to Hero  False           8.0
# 699                            Avatar: Enter The World  False           2.0
# 700                           With Aunt It's Not a Sin  False           6.3
# 724                                        Terrifier 3  False           0.0
# 770                                 Oppressive Torture  False           2.0
# 778                                  Perfect Addiction  False           0.0
# 790                                             Fast X  False           0.0
# 807                                              Porno  False           4.5
# 888              High School Girl Story Indecent Fruit  False           0.0
# 890                               Nice Sister-In-Law 2  False           6.7
# 924                                     Avatar Spirits  False           9.0
# 961                   Beauty Salon: Special Services 4  False           6.5
#
#      vote_count
# 59            6
# 60           10
# 110           7
# 138           2
# 552         146
# 699           1
# 700          10
# 724           0
# 770           2
# 778           0
# 790           0
# 807          49
# 888           0
# 890           3
# 924          14
# 961           2

# %%
df_with_missing
# Out:
#      adult     genre_ids       id original_language  \
# 59   False            []  1030419                ja
# 60   False          [99]   287003                en
# 110  False          [27]   888838                en
# 138  False          [53]   960096                es
# 552  False      [28, 16]   370455                ja
# 699  False            []   931019                en
# 700  False          [35]   367401                it
# 724  False  [27, 14, 53]  1034541                en
# 770  False            []   466353                ja
# 778  False   [10749, 18]   845659                en
# 790  False  [28, 80, 53]   385687                en
# 807  False          [18]   197158                pt
# 888  False            []   631330                ja
# 890  False       [10749]   485470                ko
# 924  False          [99]   278698                en
# 961  False       [10749]   721187                ko
#
#                    original_title  \
# 59     銀河英雄伝説 Die Neue These 策謀 1
# 60   Avatar: Scene Deconstruction
# 110           The Long Dark Trail
# 138                      El monte
# 552           ワンパンマン ロード・トゥー・ヒーロー
# 699       Avatar: Enter The World
# 700      Con la zia non è peccato
# 724                   Terrifier 3
# 770                         暴虐女拷問
# 778             Perfect Addiction
# 790                        Fast X
# 807                        Pornô!
# 888                  女子高生物語 淫らな果実
# 890                        착한 형수2
# 924                Avatar Spirits
# 961               미용실 : 특별한 서비스 4
#
#                                               overview  popularity  \
# 59                                                         373.889
# 60    The deconstruction of the Avatar scenes and sets     510.037
# 110  After two impoverished teenage brothers manage...     202.685
# 138  A father and son, isolated in a dilapidated co...     176.205
# 552  Defeating numerous villains in the abandoned a...      64.104
# 699  A behind the scenes look at the new James Came...      74.102
# 700  The rich Gloria, resident for years in the Uni...      47.484
# 724  In the aftermath of Terrifier 2, the third ins...      50.555
# 770  In the end of the 19th century, social restora...      54.348
# 778  When successful boxing trainer Sienna Lane dis...      32.530
# 790            The tenth installment in the Fast Saga.      49.774
# 807  Three tales of the erotic: Two young ladies ex...      52.780
# 888                                                         52.978
# 890  If you give it once, a good brother-in-law who...      38.071
# 924  Bryan Konietzko and Michael Dante DiMartino, c...      63.220
# 961  Focusing on the relationship between men and w...      46.956
#
#                           poster_path release_date  \
# 59   /brrgSFtcymZWaXl5a23GJRWdOSY.jpg   2022-09-30
# 60   /uCreCQFReeF0RiIXkQypRYHwikx.jpg   2009-12-18
# 110  /ebdDGnqQXDGfiggHSazaWCLF6Lf.jpg   2021-06-19
# 138  /xlwt27iWubh6DEiQhc3kyVMjCU5.jpg   2022-08-18
# 552  /bMNkufYM0kaDRJ0OVSHF91Ftdyr.jpg   2015-12-04
# 699  /9MHY9pYAgs91Ef7YFGWEbP4WJqC.jpg   2009-12-05
# 700  /qn9UmLXCpWPKcMCFWQcpF8PCq3W.jpg   1980-12-23
# 724  /A2ouWngHdomaAyFAPMI7VOpOLvS.jpg
# 770  /eVWWh9k3Mr5DQRnnjBnzdnJfE6K.jpg   1978-01-14
# 778                              None   2023-02-16
# 790  /zWJHY9QYzEcXmQ7BUg0qJxSICzd.jpg   2023-05-18
# 807  /bhbPSpYjsRJAK7rXqL8APK9EwBl.jpg   1981-01-01
# 888  /yCGcw3m94cA9ON52MrPEynkK3Fx.jpg   1997-10-10
# 890  /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 924  /oBWVyOdntLJd5bBpE0wkpN6B6vy.jpg   2010-06-22
# 961  /nJpoe1CKuiqh90qUliO6qHCeNYI.jpg   2020-05-04
#
#                                                  title  video  vote_average  \
# 59   Legend of the Galactic Heroes: Die Neue These ...  False           5.5
# 60                        Avatar: Scene Deconstruction  False           8.3
# 110                                The Long Dark Trail  False           5.1
# 138                                           The Bush  False           5.0
# 552                        One Punch Man: Road to Hero  False           8.0
# 699                            Avatar: Enter The World  False           2.0
# 700                           With Aunt It's Not a Sin  False           6.3
# 724                                        Terrifier 3  False           0.0
# 770                                 Oppressive Torture  False           2.0
# 778                                  Perfect Addiction  False           0.0
# 790                                             Fast X  False           0.0
# 807                                              Porno  False           4.5
# 888              High School Girl Story Indecent Fruit  False           0.0
# 890                               Nice Sister-In-Law 2  False           6.7
# 924                                     Avatar Spirits  False           9.0
# 961                   Beauty Salon: Special Services 4  False           6.5
#
#      vote_count
# 59            6
# 60           10
# 110           7
# 138           2
# 552         146
# 699           1
# 700          10
# 724           0
# 770           2
# 778           0
# 790           0
# 807          49
# 888           0
# 890           3
# 924          14
# 961           2
